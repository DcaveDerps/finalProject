# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv("Crime Rates in Pittsburgh.csv", index_col= "neighborhood")
data
# Out:
#                                                    number_major_crimes_1973  \
# neighborhood
# Westwood                                                                 65
# 31st ward                                                               125
# Arlington                                                               243
# Allegheny Center                                                        277
# Allegheny West                                                          154
# Allentown                                                               117
# Banksville-Greentree                                                    145
# Beechview                                                               221
# Beltzhoover                                                             293
# Bloomfield                                                              486
# Bon Air                                                                  36
# ...

# %%
data_sorted_by_1973 = data.sort_values("number_major_crimes_1973") 
data_sorted_by_1973
# Out:
#                                                    number_major_crimes_1973  \
# neighborhood
# Glen Hazel Heights                                                        0
# Ivory Avenue District                                                    10
# Swisshelm Heights                                                        18
# Chartiers City                                                           18
# City View                                                                24
# Oakwood                                                                  25
# Esplen                                                                   27
# North Side: Summer Hill Area                                             28
# Bon Air                                                                  36
# East Street Valley                                                       41
# Soho                                                                     43
# ...

# %%
safest_1973 =data_sorted_by_1973.head(5)
safest_1973
# Out:
#                        number_major_crimes_1973  neighborhood_crime_rate_1973  \
# neighborhood
# Glen Hazel Heights                            0                         0.000
# Ivory Avenue District                        10                         0.010
# Swisshelm Heights                            18                         0.009
# Chartiers City                               18                         0.015
# City View                                    24                         0.032
#
#                        number_major_crimes_1974  neighborhood_crime_rate_1974  \
# neighborhood
# Glen Hazel Heights                            0                         0.000
# Ivory Avenue District                         7                         0.007
# Swisshelm Heights                            14                         0.007
# Chartiers City                               20                         0.017
# City View                                    20                         0.027
#
# ...

# %%
data_sorted_by_1975 = data.sort_values("number_major_crimes_1975")
data_sorted_by_1975
# Out:
#                                                    number_major_crimes_1973  \
# neighborhood
# Glen Hazel Heights                                                        0
# Ivory Avenue District                                                    10
# City View                                                                24
# Swisshelm Heights                                                        18
# Chartiers City                                                           18
# Oakwood                                                                  25
# Bon Air                                                                  36
# East Street Valley                                                       41
# North Side: Summer Hill Area                                             28
# Spring Garden                                                            47
# Woods Run- Halls Grove                                                   51
# ...

# %%
safest_1975=data_sorted_by_1975.head(5)
safest_1975
# Out:
#                        number_major_crimes_1973  neighborhood_crime_rate_1973  \
# neighborhood
# Glen Hazel Heights                            0                         0.000
# Ivory Avenue District                        10                         0.010
# City View                                    24                         0.032
# Swisshelm Heights                            18                         0.009
# Chartiers City                               18                         0.015
#
#                        number_major_crimes_1974  neighborhood_crime_rate_1974  \
# neighborhood
# Glen Hazel Heights                            0                         0.000
# Ivory Avenue District                         7                         0.007
# City View                                    20                         0.027
# Swisshelm Heights                            14                         0.007
# Chartiers City                               20                         0.017
#
# ...

# %%
df_1973 = safest_1973.drop(["neighborhood_crime_rate_1973", "neighborhood_crime_rate_1974","neighborhood_crime_rate_1975"], axis=1)
df_1973
# Out:
#                        number_major_crimes_1973  number_major_crimes_1974  \
# neighborhood
# Glen Hazel Heights                            0                         0
# Ivory Avenue District                        10                         7
# Swisshelm Heights                            18                        14
# Chartiers City                               18                        20
# City View                                    24                        20
#
#                        number_major_crimes_1975
# neighborhood
# Glen Hazel Heights                            0
# Ivory Avenue District                        10
# Swisshelm Heights                            16
# Chartiers City                               20
# City View                                    15

# %%
df_1975= safest_1975.drop(["neighborhood_crime_rate_1973", "neighborhood_crime_rate_1974","neighborhood_crime_rate_1975"], axis=1)
df_1975
# Out:
#                        number_major_crimes_1973  number_major_crimes_1974  \
# neighborhood
# Glen Hazel Heights                            0                         0
# Ivory Avenue District                        10                         7
# City View                                    24                        20
# Swisshelm Heights                            18                        14
# Chartiers City                               18                        20
#
#                        number_major_crimes_1975
# neighborhood
# Glen Hazel Heights                            0
# Ivory Avenue District                        10
# City View                                    15
# Swisshelm Heights                            16
# Chartiers City                               20

# %%
df_1973.plot.bar(stacked=True)

# %%
df_1975.plot.bar(stacked=True)

# %%
df_1973.plot(kind="bar")

# %%
df_1975.plot(kind="bar")

# %%
df_1973.plot(kind="scatter", x="number_major_crimes_1973", y="number_major_crimes_1975") 
#will be same for df_1975

# %%
data.plot(kind="scatter", x="number_major_crimes_1973", y="number_major_crimes_1975", title ="Crime in 1973 vs. Crime in 1975")
